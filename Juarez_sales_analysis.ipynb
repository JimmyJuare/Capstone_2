# %%
import os
print(os.listdir('.'))           # Lists everything in current folder
print("\nData folder contents:")
print(os.listdir('data'))        # Change 'data' if your folder has a different name
# Out:
# ['customer_list.csv', 'README.md', 'StoreSales.csv', '.git', 'Products.csv', 'Juarez_sales_analysis.ipynb', 'StoreDetail.csv', 'ProductCategories.csv']
#
# Data folder contents:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 print(os.listdir('.'))           # Lists everything in current folder
#       3 print("\nData folder contents:")
# ----> 4 print(os.listdir('data'))        # Change 'data' if your folder has a different name
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'
